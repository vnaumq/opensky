# %%
from kafka import KafkaConsumer
import json

# %%
print('connecting with Kafka....')

consumer = KafkaConsumer(
    'test-topic',
    bootstrap_servers=['localhost:9092'],
    auto_offset_reset='earliest',
    value_deserializer=lambda x: json.loads(x.decode('utf-8')),
    group_id='my-first-group'
)

print('Consummer connected!')

try:
    for message in consumer:
        print("=" * 50)
        print(f"📩 ПОЛУЧЕНО СООБЩЕНИЕ:")
        print(f"   Топик: {message.topic}")
        print(f"   Партиция: {message.partition}")
        print(f"   Смещение (offset): {message.offset}")
        print(f"   Ключ: {message.key}")
        print(f"   Значение: {message.value}")
        print(f"   Время: {message.timestamp}")
        print("=" * 50)
        print()
except KeyboardInterrupt:
    print('Stopped')

consumer.close()

print('Consumer Closed')
# Out:
# connecting with Kafka....
# ---------------------------------------------------------------------------
# NoBrokersAvailable                        Traceback (most recent call last)
# Cell In[6], line 3
#       1 print('connecting with Kafka....')
# ----> 3 consumer = KafkaConsumer(
#       4     'test-topic',
#       5     bootstrap_servers=['localhost:9092'],
#       6     auto_offset_reset='earlist',
#       7     value_deserializer=lambda x: json.loads(x.decode('utf-8')),
#       8     group_id='my-first-group'
#       9 )
#      11 print('Consummer connected!')
#      13 try:
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/group.py:397, in KafkaConsumer.__init__(self, *topics, **configs)
#     393         self.config['api_version'] = tuple(map(int, str_version.split('.')))
#     394     log.warning('use api_version=%s [tuple] -- "%s" as str is deprecated',
#     395                 str(self.config['api_version']), str_version)
# --> 397 self._client = self.config['kafka_client'](metrics=self._metrics, **self.config)
#     399 # Get auto-discovered / normalized version from client
#     400 self.config['api_version'] = self._client.config['api_version']
#
# File /opt/conda/lib/python3.11/site-packages/kafka/client_async.py:262, in KafkaClient.__init__(self, **configs)
#     260 # Check Broker Version if not set explicitly
#     261 if self.config['api_version'] is None:
# --> 262     self.config['api_version'] = self.check_version()
#     263 elif self.config['api_version'] in BROKER_API_VERSIONS:
#     264     self._api_versions = BROKER_API_VERSIONS[self.config['api_version']]
#
# File /opt/conda/lib/python3.11/site-packages/kafka/client_async.py:1076, in KafkaClient.check_version(self, node_id, timeout, **kwargs)
#    1074     raise Errors.NodeNotReadyError(node_id)
#    1075 else:
# -> 1076     raise Errors.NoBrokersAvailable()
#
# NoBrokersAvailable: NoBrokersAvailable
