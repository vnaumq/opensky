# %%
import config
from sqlalchemy import text

# %%
engine = config.get_engine_postgresql()

# %%
engine
# Out:
# Engine(postgresql+psycopg2://opensky_user:***@postgres:5432/opensky)

# %%
with engine.connect() as connection:
    result = connection.execute(text("SELECT 1"))
    print(result.scalar())
# Out:
# 1
