# %%
from kafka import KafkaConsumer
import json

# %%
print('connecting with Kafka....')

consumer = KafkaConsumer(
    'test-topic',
    bootstrap_servers=['kafka:29092'],
    auto_offset_reset='earliest',
    value_deserializer=lambda x: json.loads(x.decode('utf-8')),
    group_id='my-first-group'
)

print('Consummer connected!')

try:
    for message in consumer:
        print("=" * 50)
        print(f"📩 ПОЛУЧЕНО СООБЩЕНИЕ:")
        print(f"   Топик: {message.topic}")
        print(f"   Партиция: {message.partition}")
        print(f"   Смещение (offset): {message.offset}")
        print(f"   Ключ: {message.key}")
        print(f"   Значение: {message.value}")
        print(f"   Время: {message.timestamp}")
        print("=" * 50)
        print()
except KeyboardInterrupt:
    print('Stopped')

consumer.close()

print('Consumer Closed')
# Out:
# connecting with Kafka....
# Consummer connected!
# ==================================================
# 📩 ПОЛУЧЕНО СООБЩЕНИЕ:
#    Топик: test-topic
#    Партиция: 0
#    Смещение (offset): 0
#    Ключ: None
#    Значение: {'text': 'Привет, это Маша', 'number': 1, 'timestamp': '2024-12-01'}
#    Время: 1764881231761
# ==================================================
#
# ==================================================
# 📩 ПОЛУЧЕНО СООБЩЕНИЕ:
#    Топик: test-topic
#    Партиция: 0
#    Смещение (offset): 1
#    Ключ: None
#    Значение: {'text': 'Message number: 2'}
#    Время: 1764881231762
# ==================================================
#
# ==================================================
# 📩 ПОЛУЧЕНО СООБЩЕНИЕ:
#    Топик: test-topic
#    Партиция: 0
#    Смещение (offset): 2
#    Ключ: None
#    Значение: {'text': 'Message number: 3'}
#    Время: 1764881231762
# ==================================================
#
# ==================================================
# 📩 ПОЛУЧЕНО СООБЩЕНИЕ:
#    Топик: test-topic
#    Партиция: 0
#    Смещение (offset): 3
#    Ключ: None
#    Значение: {'text': 'Message number: 4'}
#    Время: 1764881231762
# ==================================================
#
# ==================================================
# 📩 ПОЛУЧЕНО СООБЩЕНИЕ:
#    Топик: test-topic
#    Партиция: 0
#    Смещение (offset): 4
#    Ключ: None
#    Значение: {'text': 'Message number: 5'}
#    Время: 1764881231762
# ==================================================
